# %% [markdown]
# # Differential Expressed Genes (DEG) Analysis
#
# This workflow page is prepared as supplementary code for DEG and Antimicrobial Resistance analysis

# %% [markdown]
# # Differential Analysis using GSE69529 and GSE54070
# Transcriptomic datasets are available from https://www.ncbi.nlm.nih.gov/geo/. For more details of the DEG pipeline you can refer to file [DEG Using Limma](Limma_DEG.R)

# %% [markdown]
# # DEG Workflow of Analysis
#
# <img src="img/2_DEG_workflow_analysis.png"/>
#
# <center> Differential Expression Analysis of GSE69529 and GSE54070 using GEO2R Pipeline </center>
