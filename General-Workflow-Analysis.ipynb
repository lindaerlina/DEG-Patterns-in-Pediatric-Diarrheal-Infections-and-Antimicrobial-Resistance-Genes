# %% [markdown]
# # Differential Expressed Genes (DEG) and Antimicrobial Resistance Genes Analysis
#
# This workflow page is prepared as supplementary code for DEG and Antimicrobial Resistance analysis
#
# ## Tutorial sections
# This tutorial comprises the following sections:
#  1. [DEG Analysis](2_DEG_analysis.ipynb)
#  2. [Machine Learning](3_Machine_learning.ipynb)
#  3. [Antimicrobial Resistance Genes](4_AMR_Genes.ipynb)
#  4. [Protein-Protein Interaction](5_PPI_analysis.ipynb)
#  5. [Functional Enrichment Analysis](6_Enrichment_Analysis.ipynb)

# %% [markdown]
# # Introduction
# In this research, you can use transcriptomic dataset from https://www.ncbi.nlm.nih.gov/geo/.

# %% [markdown]
# # General Workflow of Analysis
#
# <img src="img/1_General_Workflow_analysis.png"/>
#
# <center> General Workflow of DEG and Antimicrobial Resistance Biomarker </center>
